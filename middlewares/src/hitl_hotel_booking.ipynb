# %% [markdown]
# Implement HITL for a hotel booking application.

# %% [markdown]
# HITL points:
#
# -   Confirm hotel
# -   Confirm room
# -   Confirm dates
# -   Confirm guests
# -   Confirm price
# -   Confirm cancellation policy
# -   Final booking approval
