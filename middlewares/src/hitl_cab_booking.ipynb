# %% [markdown]
# Implement HITL for the Cab booking application. Implement HITL before making the booking from destination A to destination B with the given fair, as well as implement hitl for the cancellation of the cab.

# %% [markdown]
# HITL points:
#
# -   Confirm pickup/drop location
# -   Confirm fare
# -   Select cab category
# -   Confirm booking
# -   Cancel ride
